# %% [markdown]
# <a href="https://colab.research.google.com/github/colawhite/dsba/blob/main/demo/decision_tree_into.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![decision_tree_example.PNG](data:image/png;base64,...)

# %% [markdown]
# ![entropy.PNG](data:image/png;base64,...)
